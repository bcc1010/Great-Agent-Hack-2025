# %%
import pandas as pd

# Load benign test cases
df = pd.read_csv('all_results.csv')

# %%
df['response'].value_counts()

# count of each unique response for each agent
df.groupby(['agent', 'response', 'dataset', 'status_code']).size().reset_index(name='count').to_csv('response_count.csv', index=False)
